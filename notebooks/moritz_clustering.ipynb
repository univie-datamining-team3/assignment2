# %%
# Load the "autoreload" extension
# %load_ext autoreload

# always reload modules marked with "%aimport"
# %autoreload 1

import os
import sys

from dotenv import load_dotenv, find_dotenv
import numpy as np
import pandas as pd

# add the 'src' directory as one where we can import modules
src_dir = os.path.join(os.getcwd(), os.pardir, 'src')
sys.path.append(src_dir)

# %aimport data.preprocessing
from data.preprocessing import Preprocessor
# %aimport data.download
from data.download import DatasetDownloader
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
data_dir = os.path.join(os.path.abspath(DatasetDownloader.get_data_dir()))
file_path = os.path.join(data_dir, "preprocessed","preprocessed_data_total.csv")
dfs = pd.read_csv(file_path, sep=';', index_col=False)

# %%
dfs.head()
# Out:
#    snippet_0  snippet_1  snippet_2  snippet_3  snippet_4  snippet_5  \
# 0   9.670845   9.680774   9.667165   9.677708   9.672548   9.677967
# 1   9.668308   9.678738   9.675576   9.674167   9.690532   9.692198
# 2   9.678036   9.662953   9.715737   9.661738   9.671797   9.699416
# 3   9.604166   9.790406   9.595141   9.680603   9.745095   9.711922
# 4   9.694020   9.707281   9.700659   9.701931   9.701505   9.685484
#
#    snippet_6  snippet_7  snippet_8  snippet_9   ...     snippet_595  \
# 0   9.668940   9.671821   9.681724   9.682986   ...        9.677611
# 1   9.681169   9.681573   9.687021   9.692332   ...        9.695430
# 2   9.689759   9.673749   9.694505   9.660014   ...        9.663122
# 3   9.606472   9.608852   9.669471   9.705075   ...        9.711997
# 4   9.705397   9.708873   9.693638   9.694002   ...        9.669317
#
#    snippet_596  snippet_597  snippet_598  snippet_599  mode      notes  \
# 0     9.680940     9.674599     9.678326     9.679511  TRAM  scripted
# ...

# %%
file_path = os.path.join(data_dir, "preprocessed","preprocessed_data.dat")
dfs_raw = Preprocessor.restore_preprocessed_data_from_disk(file_path)

# %%
sensors_data = dfs_raw['355007075245007'][1]

# %%
set(sensors_data)
# Out:
# {'acceleration', 'gyroscope', 'linacc', 'magnetic', 'rotation'}

# %%
sensors_data['location']
# Out:
#                      gpstime                    time  provider  longitude  \
# 58   2017-12-13 15:06:21.000 2017-12-13 15:06:22.078         1  16.357055
# 59   2017-12-13 15:06:21.000 2017-12-13 15:06:22.082         1  16.357055
# 60   2017-12-13 15:06:22.000 2017-12-13 15:06:22.993         1  16.357055
# 61   2017-12-13 15:06:22.000 2017-12-13 15:06:22.994         1  16.357055
# 62   2017-12-13 15:06:23.000 2017-12-13 15:06:24.005         1  16.356996
# 63   2017-12-13 15:06:23.000 2017-12-13 15:06:24.007         1  16.356996
# 64   2017-12-13 15:06:24.000 2017-12-13 15:06:24.983         1  16.356964
# 65   2017-12-13 15:06:24.000 2017-12-13 15:06:24.984         1  16.356964
# 66   2017-12-13 15:06:25.000 2017-12-13 15:06:26.022         1  16.356941
# 67   2017-12-13 15:06:25.000 2017-12-13 15:06:26.024         1  16.356941
# 68   2017-12-13 15:06:26.000 2017-12-13 15:06:26.977         1  16.356935
# 69   2017-12-13 15:06:26.000 2017-12-13 15:06:26.979         1  16.356935
# ...
